# %% [markdown]
# # Perceptron Trick:
#
#     How to Train Perceptron

# %% [markdown]
# ![Screenshot%20from%202023-11-25%2016-01-27.png](attachment:Screenshot%20from%202023-11-25%2016-01-27.png)

# %% [markdown]
# A , B , C are nothing just w1 , w2 , w3
# is ki value find out krni hai ky---> line --> correct classify
#
# first we select random student--->then check the line--> if it is not in correct place then move the line and transform the waits untill it goes into correct position
#
# Strategy:
#
#     loop--->1000 (also known as epochs)
#     while loop----> converge(correct classify)

# %% [markdown]
# # how to identify positive region and negative region

# %% [markdown]
# how to find which label exist in which line region=?
#
# ![Screenshot%20from%202023-11-25%2016-12-46.png](attachment:Screenshot%20from%202023-11-25%2016-12-46.png)

# %% [markdown]
# ![Screenshot%20from%202023-11-25%2016-14-06.png](attachment:Screenshot%20from%202023-11-25%2016-14-06.png)

# %% [markdown]
# # Transformation

# %% [raw]
# how to move line in 2d environment

# %% [markdown]
# Ax+By+c = 0
#
# if C changes then line moves:
#     ![Screenshot%20from%202023-11-25%2016-22-40.png](attachment:Screenshot%20from%202023-11-25%2016-22-40.png)

# %% [markdown]
# ![Screenshot%20from%202023-11-25%2016-27-28.png](attachment:Screenshot%20from%202023-11-25%2016-27-28.png)

# %% [markdown]
# if A changes then line moves:
#     ![Screenshot%20from%202023-11-25%2016-23-55.png](attachment:Screenshot%20from%202023-11-25%2016-23-55.png)

# %% [markdown]
# ![Screenshot%20from%202023-11-25%2016-29-51.png](attachment:Screenshot%20from%202023-11-25%2016-29-51.png)

# %% [markdown]
# if B changes then line moves
# ![Screenshot%20from%202023-11-25%2016-26-01.png](attachment:Screenshot%20from%202023-11-25%2016-26-01.png)

# %% [markdown]
# ![Screenshot%20from%202023-11-25%2016-39-13.png](attachment:Screenshot%20from%202023-11-25%2016-39-13.png)

# %% [markdown]
# # For Example:

# %% [markdown]
# ![Screenshot%20from%202023-11-25%2016-44-14.png](attachment:Screenshot%20from%202023-11-25%2016-44-14.png)

# %% [raw]
# Hum itna bara jump ni krty hai itna bara transform ni krty hai...
#
# Learning Rate use karein gay

# %% [markdown]
# # coef = coef - learningrate*coordinates

# %% [markdown]
# # Algorithm:

# %% [markdown]
# ![Screenshot%20from%202023-11-25%2016-55-51.png](attachment:Screenshot%20from%202023-11-25%2016-55-51.png)

# %% [markdown]
# ![Screenshot%20from%202023-11-25%2017-01-11.png](attachment:Screenshot%20from%202023-11-25%2017-01-11.png)

# %% [markdown]
# # Simplified Algorithm:

# %% [markdown]
# ![Screenshot%20from%202023-11-25%2017-14-22.png](attachment:Screenshot%20from%202023-11-25%2017-14-22.png)

# %% [markdown]
# # Practical Implementation:

# %% [markdown]
# # To make classification dataset:

# %%
from sklearn.datasets import make_classification
import numpy as np
X,y = make_classification(n_samples = 100 , n_features = 2,n_informative = 2, n_redundant = 0,n_classes=2,n_clusters_per_class =1 , random_state=41,hypercube = False,class_sep = 10)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
def perceptron(X,y):
    
    X = np.insert(X,0,1,axis =1)
    weights = np.ones(X.shape[1])
    lr = 0.1
    
    for i in range(1000):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
    return weights[0],weights[1:]

# %%
def step(z):
    return 1 if z>0 else 0

# %%
intercept_,coef_ = perceptron(X,y)

# %%
print(coef_)
# Out:
# [-0.73016234  0.4845591 ]

# %%
print(intercept_)
# Out:
# 0.9

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input+b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color = 'red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c = y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
