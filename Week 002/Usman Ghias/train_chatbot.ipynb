# %% [markdown]
# # $$ Train ChatBot $$

# %% [markdown]
# ## Import Libraries and Load the Data

# %%
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

# %% [markdown]
# **Code Explanation:**
# - `numpy` is imported as `np` for numerical operations.
# - `Sequential` is a model type in Keras that allows you to build a neural network layer by layer.
# - `Dense` is a layer type for creating densely-connected neural network layers.
# - `Activation` is used to specify the activation functions for layers.
# - `Dropout` is used to add dropout regularization to the model.
# - `SGD` stands for Stochastic Gradient Descent, which is an optimization algorithm used for training the neural network.
# - `random` is imported for generating random numbers and is used in various parts of the code.

# %%
# Import necessary libraries for text processing
import nltk
from nltk.stem import WordNetLemmatizer

# Initialize a lemmatizer for word normalization
lemmatizer = WordNetLemmatizer()
 
# Import JSON and Pickle for data serialization
import json
import pickle

# %% [markdown]
# **Code Explanation:**
# - `nltk` is a powerful library for natural language processing. It provides tools for working with text data.
# - We import the `WordNetLemmatizer` from `nltk.stem`. A lemmatizer is a tool used to reduce words to their base or dictionary form. This is helpful for text analysis as it reduces words to their common form (e.g., "running" to "run").
# - `json` is imported to work with JSON data. JSON is a common data format for storing and exchanging structured data.
# - `pickle` is imported to work with Python object serialization. It allows us to save and load Python objects like variables or models.

# %%
intents_file = open('intents.json').read()
intents = json.loads(intents_file)

# %% [markdown]
# ## Preprocessing the Data

# %% [markdown]
# ### Tokenization: Preparing Text Data for Analysis
#
# In natural language processing (NLP) and machine learning, the data used by models cannot be raw text; it needs to go through a series of pre-processing steps to make it more suitable for analysis. One of the fundamental preprocessing techniques for textual data is "tokenization."
#
# **Tokenization** is the process of breaking down sentences or paragraphs into individual words or tokens. These tokens are the basic building blocks that enable machines to understand and work with textual data. In our code, we use tokenization to convert raw text into a more structured format, making it easier for the machine to analyze.
#
# Here's why tokenization is important in our project:
#
# - In our project, we are working with intents, which are essentially groups of user queries or patterns and corresponding responses. Each intent is associated with a specific category or purpose, like "greeting," "farewell," or "ordering."
#
# - To prepare this textual data for analysis, we tokenize each pattern. This means that we break down sentences or user queries into individual words. For example, the sentence "How are you doing?" would be tokenized into individual tokens like "How," "are," "you," and "doing."
#
# - The tokenized words are then collected into lists, making it easier for us to manage and work with the textual data. For instance, all the tokens from various user queries associated with a particular intent are stored in a list.
#
# - Additionally, we maintain a list of classes, which represents the categories or intents. Each intent is associated with specific patterns. This list of classes helps us understand the scope of our project and categorize user queries effectively.

# %%
# Initialize empty lists for words, classes, and documents
words = []
classes = []
documents = []

# Define a list of characters to ignore
ignore_letters = ['!', '?', ',', '.']

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)        
        #add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

print(documents)
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['How', 'you', 'could', 'help', 'me', '?'], 'options'), (['What', 'you', 'can', 'do', '?'], 'options'), (['What', 'help', 'you', 'provide', '?'], 'options'), (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'), (['What', 'support', 'is', 'offered'], 'options'), (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'), (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'), (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug'), (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug'), (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug'), (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'), (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'), (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'), (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search'), (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'), (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'), (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search'), (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search'), (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'), (['Find', 'pharmacy'], 'pharmacy_search'), (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'), (['Locate', 'pharmacy'], 'pharmacy_search'), (['Search', 'pharmacy'], 'pharmacy_search'), (['Lookup', 'for', 'hospital'], 'hospital_search'), (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search'), (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'), (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'), (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %% [markdown]
# **Explanation:**
# - The code is designed to process a dataset of intents, where each intent represents a specific category or type of user input (e.g., "greeting," "farewell," "ordering").
# - It loops through each intent within the 'intents' dataset.
# - Inside each intent, it iterates through the 'patterns,' which are examples of user queries or sentences associated with that intent.
# - For each pattern, it tokenizes the text, which means it breaks down the sentence into individual words. This is important for understanding and analyzing the text because it separates words from one another.
# - The tokenized words are then added to the 'words' list, which accumulates all the words from all the patterns and intents.
# - Additionally, the code creates a 'documents' list. This list stores the tokenized words along with their associated intent tags. This is useful for training a machine learning model to understand which intents are associated with which words.
# - The 'classes' list keeps track of all the intent tags encountered. If a tag is not already in the list, it is added.
# - The purpose of this code is to prepare and structure textual data for a chatbot or natural language processing application. By tokenizing the text and organizing it into lists, it becomes easier to analyze, classify, and respond to user input effectively.
# - The final 'print' statement is there to show the 'documents' list, which is a structured representation of the data that will be used to train a chatbot or perform further NLP tasks. This 'documents' list will contain tokenized patterns and their corresponding intent tags, which are crucial for understanding user intent and generating appropriate responses.

# %% [markdown]
# # $$ Lemmatization $$
#  - We are applying lemmatization to every word in our dataset. By doing so, we remove duplicates and ensure that our model considers different word forms as a unified concept. This step is crucial for making our model more efficient and capable of handling a wide range of user inputs effectively.

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Usman
# [nltk_data]     Ghias\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatized words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %% [markdown]
# ### This code snippet demonstrates the following:
#
# - Lemmatizes each word, converts them to lowercase, and removes duplicates. This step further prepares the words for use in a machine learning model.
# - Sorts the unique intent classes and prints the count.
# - Counts the number of documents (combinations of patterns and intents), intent classes, and unique lemmatized words.
# - Serializes and saves the processed words and intent classes to files using Pickle for future use, such as training a chatbot or natural language processing model.
#
# The purpose of this code is to finalize the preprocessing of textual data, ensuring that words are in their lemmatized and lowercase form while saving these processed words and intent classes for future use in machine learning tasks.

# %% [markdown]
# # Create Training and Testing Data

# %%
import numpy as np

# Create the training data
training = []
output_empty = [0] * len(classes)

for doc in documents:
    bag = []
    word_patterns = doc[0]
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
    
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# Shuffle the training data
random.shuffle(training)

# Separate the bag and output rows into NumPy arrays
train_x = np.array([item[0] for item in training])
train_y = np.array([item[1] for item in training])

print("Training data is created")
# Out:
# Training data is created

# %% [markdown]
# # Training the Model

# %%
# deep neural networks model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compiling model. Use the recommended optimizer arguments.
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Training and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("Model is created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 1s 6ms/step - loss: 2.2117 - accuracy: 0.2340
# Epoch 2/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1657 - accuracy: 0.1064
# Epoch 3/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0826 - accuracy: 0.2128
# Epoch 4/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0074 - accuracy: 0.3191
# Epoch 5/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.8793 - accuracy: 0.4255
# Epoch 6/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7619 - accuracy: 0.4255
# Epoch 7/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6773 - accuracy: 0.5106
# Epoch 8/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.4728 - accuracy: 0.6809
# Epoch 9/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3029 - accuracy: 0.6596
# Epoch 10/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2986 - accuracy: 0.5957
# Epoch 11/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0874 - accuracy: 0.7660
# Epoch 12/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0800 - accuracy: 0.7447
# Epoch 13/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9255 - accuracy: 0.7872
# Epoch 14/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8173 - accuracy: 0.8085
# Epoch 15/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7787 - accuracy: 0.7234
# Epoch 16/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6497 - accuracy: 0.8723
# Epoch 17/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6865 - accuracy: 0.7872
# Epoch 18/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5251 - accuracy: 0.8936
# Epoch 19/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5146 - accuracy: 0.8298
# Epoch 20/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4215 - accuracy: 0.9574
# Epoch 21/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3323 - accuracy: 0.9362
# Epoch 22/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3677 - accuracy: 0.8936
# Epoch 23/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5746 - accuracy: 0.7660
# Epoch 24/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2180 - accuracy: 0.9787
# Epoch 25/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2951 - accuracy: 0.8936
# Epoch 26/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3413 - accuracy: 0.9362
# Epoch 27/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3660 - accuracy: 0.8298
# Epoch 28/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1876 - accuracy: 0.9574
# Epoch 29/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2821 - accuracy: 0.9362
# Epoch 30/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2307 - accuracy: 0.9149
# Epoch 31/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1897 - accuracy: 0.9787
# Epoch 32/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1588 - accuracy: 0.9362
# Epoch 33/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2284 - accuracy: 0.9574
# Epoch 34/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2494 - accuracy: 0.9574
# Epoch 35/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2028 - accuracy: 0.9574
# Epoch 36/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1699 - accuracy: 0.9574
# Epoch 37/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1786 - accuracy: 0.9149
# Epoch 38/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1572 - accuracy: 0.9574
# Epoch 39/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1413 - accuracy: 0.9787
# Epoch 40/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1385 - accuracy: 0.9787
# Epoch 41/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0977 - accuracy: 0.9574
# Epoch 42/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1336 - accuracy: 0.9787
# Epoch 43/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1262 - accuracy: 0.9787
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1248 - accuracy: 0.9787
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2075 - accuracy: 0.9149
# Epoch 46/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0503 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1352 - accuracy: 0.9787
# Epoch 48/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2661 - accuracy: 0.9149
# Epoch 49/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1317 - accuracy: 0.9787
# Epoch 50/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2582 - accuracy: 0.9362
# Epoch 51/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0567 - accuracy: 1.0000
# Epoch 52/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0617 - accuracy: 0.9787
# Epoch 53/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2062 - accuracy: 0.9362
# Epoch 54/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0689 - accuracy: 0.9787
# Epoch 55/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1060 - accuracy: 0.9787
# Epoch 56/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1555 - accuracy: 0.9574
# Epoch 57/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0962 - accuracy: 0.9574
# Epoch 58/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0745 - accuracy: 0.9787
# Epoch 59/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0656 - accuracy: 0.9787
# Epoch 60/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1236 - accuracy: 0.9787
# Epoch 61/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1068 - accuracy: 0.9787
# Epoch 62/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1028 - accuracy: 0.9574
# Epoch 63/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1814 - accuracy: 0.9362
# Epoch 64/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0816 - accuracy: 0.9787
# Epoch 65/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0898 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0956 - accuracy: 0.9574
# Epoch 67/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0686 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0492 - accuracy: 1.0000
# Epoch 69/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1077 - accuracy: 0.9787
# Epoch 70/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0730 - accuracy: 0.9787
# Epoch 71/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0458 - accuracy: 0.9787
# Epoch 72/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0392 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0456 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1264 - accuracy: 0.9574
# Epoch 76/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1080 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0432 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0557 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0353 - accuracy: 0.9787
# Epoch 82/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0491 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0616 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0621 - accuracy: 0.9787
# Epoch 87/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0609 - accuracy: 0.9787
# Epoch 90/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0670 - accuracy: 0.9787
# Epoch 91/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0900 - accuracy: 0.9574
# Epoch 92/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0827 - accuracy: 0.9787
# Epoch 94/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0553 - accuracy: 0.9787
# Epoch 96/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0330 - accuracy: 0.9787
# Epoch 98/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0451 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0371 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0622 - accuracy: 0.9787
# Epoch 101/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0496 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0924 - accuracy: 0.9787
# Epoch 109/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0792 - accuracy: 0.9787
# Epoch 110/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0869 - accuracy: 0.9574
# Epoch 111/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0462 - accuracy: 0.9787
# Epoch 113/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0686 - accuracy: 0.9574
# Epoch 114/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0456 - accuracy: 0.9787
# Epoch 115/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0672 - accuracy: 0.9787
# Epoch 116/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0949 - accuracy: 0.9787
# Epoch 118/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1554 - accuracy: 0.9574
# Epoch 120/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1311 - accuracy: 0.9362
# Epoch 121/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0528 - accuracy: 0.9787
# Epoch 124/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0869 - accuracy: 0.9787
# Epoch 136/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0565 - accuracy: 0.9787
# Epoch 137/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0877 - accuracy: 0.9787
# Epoch 139/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0837 - accuracy: 0.9362
# Epoch 142/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0337 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0631 - accuracy: 0.9787
# Epoch 145/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 0.9787
# Epoch 148/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0329 - accuracy: 0.9787
# Epoch 149/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0731 - accuracy: 0.9787
# Epoch 151/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0466 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0863 - accuracy: 0.9362
# Epoch 154/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0702 - accuracy: 0.9787
# Epoch 157/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0437 - accuracy: 0.9787
# Epoch 158/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0999 - accuracy: 0.9787
# Epoch 170/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0411 - accuracy: 0.9787
# Epoch 174/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0440 - accuracy: 0.9787
# Epoch 180/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9574
# Epoch 181/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0518 - accuracy: 0.9787
# Epoch 185/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0568 - accuracy: 0.9787
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Model is created
# C:\Users\Usman Ghias\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# **Model Architecture and Training:**
#
# Our model is designed as a neural network consisting of three dense layers. Each layer serves a specific purpose in understanding and classifying user inputs:
#
# 1. **First Layer (128 Neurons):** This initial layer processes the input data and extracts relevant features. With 128 neurons, it can capture a variety of patterns and information.
#
# 2. **Second Layer (64 Neurons):** The second layer further refines the feature representation with 64 neurons. This reduces the complexity of the data while retaining crucial information.
#
# 3. **Last Layer (Number of Classes Neurons):** The final layer is tailored to the number of unique intent classes we have. It's where the model makes predictions about which intent best matches the input.
#
# **Dropout Layers:**
#
# To prevent overfitting, we've introduced dropout layers. These layers randomly deactivate a fraction of neurons during each training iteration, ensuring that the model doesn't become too specialized on the training data. This promotes better generalization to unseen inputs.
#
# **Optimizer:**
#
# We've employed the Stochastic Gradient Descent (SGD) optimizer for training our model. SGD is a widely used optimization algorithm for updating model weights during training. It helps the model converge to a solution more effectively.
#
# **Training:**
#
# We feed our preprocessed and tokenized data into the model and train it. In this code, the model is trained over 200 epochs, which means it goes through the entire dataset 200 times. This extensive training allows the model to learn patterns and associations in the data.
#
# **Model Saving:**
#
# Once the training is complete, we save the trained model using Keras' `model.save("chatbot_model.h5")` function. This saved model can be used for chatbot development or other natural language processing tasks without the need to retrain it from scratch. It preserves the learned patterns and relationships in the data, making it ready for deployment in practical applications.
