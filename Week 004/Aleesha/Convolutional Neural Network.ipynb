# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# Convolutional neural networks, also known as convnet or CNNs, are a special kind of neural network for processing data that has a known grid-like topology like time series data(1D) or images(2D)

# %% [raw]
# Difference between CNN and ANN:
# In ANN-----> matrix multiplication
# In CNN-----> Convolutional Operations

# %% [markdown]
# # Layers in CNN:

# %% [raw]
# Convolutional Layer
# Pooling Layer
# Fully Connected Layer

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2018-43-35.png](attachment:Screenshot%20from%202023-11-11%2018-43-35.png)

# %% [markdown]
# By using ANN(matrix Multiplication)---->To much Computational Process

# %% [markdown]
# # How Human Recognize any Image:

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2018-54-07.png](attachment:Screenshot%20from%202023-11-11%2018-54-07.png)

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2019-10-23.png](attachment:Screenshot%20from%202023-11-11%2019-10-23.png)

# %% [markdown]
# # How can we make computers recognize these tiny Features?

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2019-14-15.png](attachment:Screenshot%20from%202023-11-11%2019-14-15.png)
#
#
#
# We use the concept of  Filter
# We have three filters

# %% [markdown]
# # We take original Image------>We will apply convolutional operation or filter Operation.

# %% [markdown]
# # Orginal Image vs Loopy pattern image

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2019-18-30.png](attachment:Screenshot%20from%202023-11-11%2019-18-30.png)

# %% [markdown]
# Make the patch of 3 by 3 4 by 4 5 by 5 and multiply with loopy pattern and get the result and put it on feature map

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2019-23-24.png](attachment:Screenshot%20from%202023-11-11%2019-23-24.png)

# %% [markdown]
# # We Get Feature Map:

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2019-25-54.png](attachment:Screenshot%20from%202023-11-11%2019-25-54.png)

# %% [markdown]
# This 1 means which highlight---> Here is the loopy pattern

# %% [markdown]
# # Loopy Pattern Detector
#
# where It finds loopy pattern--->it activates

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2019-28-09.png](attachment:Screenshot%20from%202023-11-11%2019-28-09.png)

# %% [markdown]
# # So, Filters are nothing but the Feature Detector

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2019-32-08.png](attachment:Screenshot%20from%202023-11-11%2019-32-08.png)

# %% [markdown]
# # 1-D

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2019-34-51.png](attachment:Screenshot%20from%202023-11-11%2019-34-51.png)

# %% [markdown]
# # 2-D

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2019-36-33.png](attachment:Screenshot%20from%202023-11-11%2019-36-33.png)

# %% [markdown]
# # Fully Connected Dense Neural Network

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2019-38-51.png](attachment:Screenshot%20from%202023-11-11%2019-38-51.png)

# %% [markdown]
# So CNN------> Feature Extraction
# and Dense Neural Network -----> For Classification

# %% [markdown]
# # Relu

# %% [markdown]
# -ve value------> zero
# +ve value------> as it is
#
#
# ![Screenshot%20from%202023-11-11%2019-42-50.png](attachment:Screenshot%20from%202023-11-11%2019-42-50.png)

# %% [markdown]
# # But we didn't address the issue of to much Computation, we don't reduce the image Size

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2019-45-12.png](attachment:Screenshot%20from%202023-11-11%2019-45-12.png)

# %% [markdown]
# # Pooling layer is used to reduce the Size

# %% [markdown]
# In Max-Pooling we Pick maximum number like in yellow portion we pick maximum 8---> in pink portion we pick maximum 9 and so on
#
#
# ![Screenshot%20from%202023-11-11%2019-49-00.png](attachment:Screenshot%20from%202023-11-11%2019-49-00.png)

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2019-50-45.png](attachment:Screenshot%20from%202023-11-11%2019-50-45.png)

# %% [markdown]
# # Benefits of Pooling:

# %% [raw]
# Reduces Dimensions and Computation
#
# Reduce overfitting as there are less parameters
#
# Model is tolerant towards variations, distortions

# %% [markdown]
# # Overall Convolutional Neural Network

# %% [markdown]
# ![Screenshot%20from%202023-11-11%2019-54-52.png](attachment:Screenshot%20from%202023-11-11%2019-54-52.png)
